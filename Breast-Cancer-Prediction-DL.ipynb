# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
load_dataset = load_breast_cancer(as_frame=True)
df = pd.concat([load_dataset.data, load_dataset.target], axis=1)
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
# plotting outliers
plt.figure(figsize=(12, 35))
for f in range(len([i for i in df.columns if i != 'target'])):
    plt.subplot(10, 3, f + 1)
    plt.boxplot(df.iloc[:, f])

plt.show()

# %%
from sklearn.preprocessing import minmax_scale

df_scaled = pd.DataFrame(minmax_scale(df), columns=df.columns)
df_scaled
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0       0.521037      0.022658        0.545989   0.363733         0.593753
# 1       0.643144      0.272574        0.615783   0.501591         0.289880
# 2       0.601496      0.390260        0.595743   0.449417         0.514309
# 3       0.210090      0.360839        0.233501   0.102906         0.811321
# 4       0.629893      0.156578        0.630986   0.489290         0.430351
# ..           ...           ...             ...        ...              ...
# 564     0.690000      0.428813        0.678668   0.566490         0.526948
# 565     0.622320      0.626987        0.604036   0.474019         0.407782
# 566     0.455251      0.621238        0.445788   0.303118         0.288165
# 567     0.644564      0.663510        0.665538   0.475716         0.588336
# 568     0.036869      0.501522        0.028540   0.015907         0.000000
#
# ...

# %%
X = df_scaled[[i for i in df_scaled.columns if i != 'target']]
y = df_scaled['target']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Input

# %%
model = Sequential()
model.add(Input(shape=30))
model.add(Dense(90, activation='relu'))
model.add(Dense(25, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam())
model.fit(X_train, y_train, epochs=50)

y_pred = np.round(model.predict(X_test))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 2s 3ms/step - loss: 0.2250
# Epoch 2/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1832
# Epoch 3/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1480
# Epoch 4/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1172
# Epoch 5/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0945
# Epoch 6/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0785
# Epoch 7/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0660
# Epoch 8/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0598
# Epoch 9/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0535
# Epoch 10/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0486
# Epoch 11/50
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0450
# Epoch 12/50
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0414
# ...

# %%
from sklearn.metrics import (classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay)

print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9590643274853801
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.89      0.94        64
#          1.0       0.94      1.00      0.97       107
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
cmd = ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred))
cmd.plot(cmap=plt.cm.Blues)
plt.show()

# %%
from ann_visualizer.visualize import ann_viz

ann_viz(model)
